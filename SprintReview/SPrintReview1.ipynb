// %%
public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public decimal Price
    {
        get { return price; }
        set { price = value; }
    }

    public int Quantity
    {
        get { return quantity; }
        set { quantity = value; }
    }

    public string Category
    {
        get { return category; }
        set { category = value; }
    }

    public string Description
    {
        get { return description; }
        set { description = value; }
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int amount)
    {
        quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Товар: {name}, Цена: {price} руб., Кол-во: {quantity}, Категория: {category}";
    }
}

public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;
    private List<Product> products = new List<Product>();

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public decimal Salary
    {
        get { return salary; }
        set { salary = value; }
    }

    public string ContactInfo
    {
        get { return contactInfo; }
        set { contactInfo = value; }
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
    }

    public void SellProduct(Product product, int quantity)
    {
        if (product.Quantity >= quantity)
        {
            product.UpdateQuantity(-quantity);
            Console.WriteLine($"Продано {quantity} шт. товара {product.Name}");
        }
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {name}, ID: {employeeId}, Зарплата: {salary} руб.";
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;
    private List<Seller> sellers = new List<Seller>();
    private List<Product> products = new List<Product>();

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public string StoreHours
    {
        get { return storeHours; }
        set { storeHours = value; }
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
    }

    public void ListProducts()
    {
        Console.WriteLine($"Товары в магазине {storeName}:");
        foreach (var product in products)
        {
            Console.WriteLine(product.GetProductInfo());
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {storeName}, Адрес: {location}";
    }
}

Product laptop = new Product("Ноутбук", 50000, 10, "Электроника", "Игровой");
Product shirt = new Product("Футболка", 1500, 50, "Одежда", "Хлопковая");

Seller seller = new Seller("Иван Иванов", "EMP001", 50000, "+79991234567");
Store store = new Store("ТехноМир", "ул. Пушкина, 10", "9:00-21:00");

seller.AddProduct(laptop);
seller.AddProduct(shirt);

store.AddProduct(laptop);
store.AddProduct(shirt);
store.AddSeller(seller);

Console.WriteLine("Информация о магазине");
Console.WriteLine(store.GetStoreInfo());
Console.WriteLine(seller.GetSellerInfo());

Console.WriteLine("\nТовары в магазине");
store.ListProducts();

Console.WriteLine("\nПродажа товаров");
seller.SellProduct(laptop, 2);
seller.SellProduct(shirt, 3);

Console.WriteLine("\nПосле продажи");
store.ListProducts();

Console.WriteLine($"\nОбщая стоимость ноутбуков: {laptop.GetTotalPrice()} руб.");
Console.WriteLine($"Общая стоимость футболок: {shirt.GetTotalPrice()} руб.");
// Out:
// Информация о магазине
// Магазин: ТехноМир, Адрес: ул. Пушкина, 10
// Продавец: Иван Иванов, ID: EMP001, Зарплата: 50000 руб.
//
// Товары в магазине
// Товары в магазине ТехноМир:
// Товар: Ноутбук, Цена: 50000 руб., Кол-во: 10, Категория: Электроника
// Товар: Футболка, Цена: 1500 руб., Кол-во: 50, Категория: Одежда
//
// Продажа товаров
// Продано 2 шт. товара Ноутбук
// Продано 3 шт. товара Футболка
//
// После продажи
// Товары в магазине ТехноМир:
// Товар: Ноутбук, Цена: 50000 руб., Кол-во: 8, Категория: Электроника
// Товар: Футболка, Цена: 1500 руб., Кол-во: 47, Категория: Одежда
//
// Общая стоимость ноутбуков: 400000 руб.
// Общая стоимость футболок: 70500 руб.
